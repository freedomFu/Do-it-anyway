# %% [markdown]
# ### 统计四大中带有 mail 或者 email 关键词的论文数目

# %%
ccs_dict = {
    "2024": [
        "Inbox Invasion: Exploiting MIME Ambiguities to Evade Email Attachment Detectors",
    ],
    "2023": [],
    "2022": [],
    "2021": [],
    "2020": [
        "Mitigation of Attacks on Email End-to-End Encryption"
    ],
    "2019": [],
    "2018": [],
    "2017": [],
    "2016": [],
    "2015": [
        "Security by Any Other Name: On the Effectiveness of Provider Based Email Security"
    ],
    "2014": [],
    "2013": [],
    "2012": [],
    "2011": [],
    "2010": [],
    "2009": [],
    "2008": [],
    "2007": [],
    "2006": [
        "An effective defense against email spam laundering"
    ],
    "2005": [],
    "2004": [],
    "2003": [],
    "2002": [],
    "2001": [],
    "2000": [],
    "1999": [],
    "1998": [
        "The Design, Implementation and Operation of an Email Pseudonym Server"
    ],
    "1997": [],
    "1996": [
        "Secure External References in Multimedia Email Messages"    
    ],
    "1994": [
        "Support for the File System Security Requirements of Computational E-Mail Systems"
    ],
    "1993": []
}

ndss_dict = {
    "2025": [
        "A Multifaceted Study on the Use of TLS and Auto-detect in Email Ecosystems",
        "Automatic Insecurity: Exploring Email Auto-configuration in the Wild",
        "HADES Attack: Understanding and Evaluating Manipulation Risks of Email Blocklists",
        "Cascading Spy Sheets: Exploiting the Complexity of Modern CSS for Email and Browser Fingerprinting"
    ],
    "2024": [],
    "2023": [],
    "2022": [],
    "2021": [],
    "2020": [],
    "2019": [],
    "2018": [],
    "2017": [],
    "2016": [],
    "2015": [],
    "2014": [
        "Enhanced Certificate Transparency and End-to-End Encrypted Mail"
    ],
    "2013": [],
    "2012": [],
    "2011": [],
    "2010": [],
    "2009": [],
    "2008": [],
    "2007": [],
    "2006": [],
    "2005": [],
    "2004": [],
    "2003": [
        "Fighting Spam by Encapsulating Policy in Email Addresses"
    ],
    "2002": [],
    "2001": [
        "TRICERT: A Distributed Certified E-Mail Scheme"
    ],
    "2000": [],
    "1999": [],   
    "1998": [],   
    "1997": [],   
    "1996": [
        "Mixing Email with Babel"
    ]
}

usenix_sec_dict = {
    "2024": [
        "FakeBehalf: Imperceptible Email Spoofing Attacks against the Delegation Mechanism in Email Systems",
        "Assessing Suspicious Emails with Banner Warnings Among Blind and Low-Vision Users in Realistic Settings"        
    ],
    "2023": [
        "Content-Type: multipart/oracle - Tapping into Format Oracles in Email End-to-End Encryption",
        "Extended Hell(o): A Comprehensive Large-Scale Study on Email Confidentiality and Integrity Mechanisms in the Wild"
    ],
    "2022": [
        "Leaky Forms: A Study of Email and Password Exfiltration Before Form Submission"
    ],
    "2021": [
        "KeyForge: Non-Attributable Email from Forward-Forgeable Signatures",
        "Weak Links in Authentication Chains: A Large-scale Analysis of Email Sender Spoofing Attacks",
        "Why TLS is better without STARTTLS: A Security Analysis of STARTTLS in the Email Context"
    ],
    "2020": [
        "A Longitudinal and Comprehensive Study of the DANE Ecosystem in Email",
        "Composition Kills: A Case Study of Email Sender Authentication"
    ],
    "2019": [
        "\"Johnny, you are fired!\" - Spoofing OpenPGP and S/MIME Signatures in Emails",
        "High Precision Detection of Business Email Compromise"
    ],
    "2018": [
        "Efail: Breaking S/MIME and OpenPGP Email Encryption using Exfiltration Channels",
        "End-to-End Measurements of Email Spoofing Attacks"
    ],
    "2017": [],
    "2016": [],
    "2015": [],
    "2014": [],
    "2013": [],
    "2012": [
        "B@bel: Leveraging Email Delivery for Spam Mitigation"
    ],
    "2011": [],
    "2010": [],
    "2009": [],
    "2008": [],
    "2007": [],
    "2006": [],
    "2005": [],
    "2004": [],
    "2003": [
        "Domain-Based Administration of Identity-Based Cryptosystems for Secure Email and IPSEC"
    ],
    "2002": [],
    "2001": [],
    "2000": [
        "A Chosen Ciphertext Attack Against Several E-Mail Encryption Protocols",
        "Shibboleth: Private Mailing List Manager"
    ],
    "1999":[],
    "1998":[],
    "1996":[],
    "1995":[],
    "1993":[
        "Sendmail Without the Superuser"
    ]
}

soups_dict = {
    "2024": [],
    "2023": [
        "Checking, nudging or scoring? Evaluating e-mail user security tools",
        "Understanding the Viability of Gmail's Origin Indicator for Identifying the Sender",
        "Distrust of big tech and a desire for privacy: Understanding the motivations of people who have voluntarily adopted secure email"
    ],
    "2022": [
        "\"I don't know why I check this...\" - Investigating Expert Users' Strategies to Detect Email Signature Spoofing Attacks",
        "Presenting Suspicious Details in User-Facing E-mail Headers Does Not Improve Phishing Detection"
    ],
    "2021": [
        "Why They Ignore English Emails: The Challenges of Non-Native Speakers in Identifying Phishing Emails"
    ],
    "2020": [],
    "2019": [],
    "2018": [
        "A Comparative Usability Study of Key Management in Secure Email"
    ],
    "2017": [],
    "2016": [],
    "2015": [],
    "2014": [],
    "2013": [],
    "2012": [],
    "2011": [],
    "2010": [],
    "2009": [],
    "2008": [],
    "2007": [
        "Facemail: showing faces of recipients to prevent misdirected email"    
    ],
    "2006": [],
    "2005": []
}

sp_dict = {
    "2024": [],
    "2023": [
        "Design and Evaluation of Inclusive Email Security Indicators for People with Visual Impairments"
    ],
    "2022": [
        "27 Years and 81 Million Opportunities Later: Investigating the Use of Email Encryption for an Entire University"
    ],
    "2021": [],
    "2020": [],
    "2019": [
        "Characterizing Pixel Tracking through the Lens of Disposable Email Services"
    ],
    "2018": [],
    "2017": [],
    "2016": [],
    "2015": [],
    "2014": [],
    "2013": [],
    "2012": [],
    "2011": [],
    "2010": [],
    "2009": [],
    "2008": [],
    "2007": [],
    "2006": [],
    "2005": [],
    "2004": [],
    "2003": [],
    "2002": [],
    "2001": [],
    "2000": [],
    "1999": [],
    "1998": [],
    "1997": [],
    "1996": [],
    "1995": [],
    "1994": [],
    "1993": [],
    "1992": [],
    "1991": [],
    "1990": [
        "The Role of Trust in Protected Mail"
    ],
    "1989": [],
    "1988": [],
    "1987": [],
    "1986": [],
    "1985": [],
    "1984": [],
    "1983": [],
    "1982": [],
    "1981": [],
    "1980": [],
}

imc_dict = {
    "2024": [
        "Bounce in the Wild: A Deep Dive into Email Delivery Failures from a Large Email Service Provider"
    ],
    "2023": [],
    "2022": [
        "SPFail: discovering, measuring, and remediating vulnerabilities in email sender validation"    
    ],
    "2021": [
        "Who's got your mail?: characterizing mail service provider usage"
    ],
    "2020": [
        "Who is targeted by email-based phishing and malware?: Measuring factors that differentiate risk"
    ],
    "2019": [],
    "2018": [],
    "2017": [
        "Email typosquatting"
    ],
    "2016": [
        "What Happens After You Are Pwnd: Understanding the Use of Leaked Webmail Credentials in the Wild"
    ],
    "2015": [
        "Neither Snow Nor Rain Nor MITM...: An Empirical Analysis of Email Delivery Security"
    ],
    "2014": [],
    "2013": [],
    "2012": [
        "Observing common spam in Twitter and email"
    ],
    "2011": [],
    "2010": [
        "Digging into HTTPS: flow-based classification of webmail traffic"
    ],
    "2009": [],
    "2008": [],
    "2007": [],
    "2006": [],
    "2005": [],
    "2004": [],
    "2003": [],
    "2002": [],
    "2001": []
}

# %%
from __future__ import print_function, division 
from collections import defaultdict 
from loguru import logger 
from datetime import datetime 
import math 
import binascii 
import bcrypt 
import re 
import string 
import os 
import shutil 
import csv 
import json 
import pickle 
from collections import Counter 
import random 
from tqdm import tqdm 
import matplotlib.ticker as mtick 
from matplotlib.pyplot import MultipleLocator 
import numpy as np 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
from matplotlib.ticker import FuncFormatter 
# from matplotlib_venn import venn2, venn3, venn2_circles 
import venn 
import pandas as pd 
# %matplotlib inline 
plt.rcParams['figure.figsize'] = (16, 8) 
TEST_SAMPLE_SIZE = 20000 
MAX_GN = 1000  

all_dicts = [
    ccs_dict,
    ndss_dict,
    usenix_sec_dict,
    soups_dict,
    sp_dict,
    imc_dict
]

years = range(2000, 2026)
counts_per_dict = []

for dictionary in tqdm(all_dicts):
    counts = [0] * len(years)  # 初始化每个年份的文献数为0
    for i, year in enumerate(years):
        year_str = str(year)
        counts[i] = len(dictionary.get(year_str, []))  # 统计对应年份的文献数量
    counts_per_dict.append(counts)
    
sum_count = []

for i in range(len(counts_per_dict[0])):
    sum_count.append(
        counts_per_dict[0][i] + 
        counts_per_dict[1][i] + 
        counts_per_dict[2][i] + 
        counts_per_dict[3][i] + 
        counts_per_dict[4][i] + 
        counts_per_dict[5][i]
    )

COLOR1 = '#808080'  
COLOR2 = '#74b131' 
COLOR3 = "#3ba4d9" 
COLOR4 = "#ec591c" 
COLOR5 = '#7e017f' 
COLOR6 = '#c31685' 
COLOR7 = '#9d010d' 
COLOR8 = '#5561ce' 
COLOR9 = '#000000'  

#曲线类型  
Style1 = (0, (3, 1, 1, 1, 5, 1)) 
Style2 = (0, (8, 1)) 
Style3 = (0, (5, 1, 1, 1)) 
Style4 = (0, (3, 1)) 
Style5 = ':' 
Style6 = (0, (5, 1, 1, 1, 1, 1)) 
Style7 = (0, (12, 1)) 
Style8 = 'solid' 
Style9 = (0, (5, 1, 3, 1, 1, 1)) 

year_range = pd.date_range(start='2000-01-01', end='2025-12-31', freq='Y')
step = 1
x_ticks = year_range[::step]
x_labels = x_ticks.strftime('%Y').tolist()

p1, = plt.plot(year_range, counts_per_dict[0], label='ACM CCS', color = COLOR1, linewidth = '3', linestyle = Style1)
p2, = plt.plot(year_range, counts_per_dict[1], label='NDSS', color = COLOR2, linewidth = '3', linestyle = Style2)
p3, = plt.plot(year_range, counts_per_dict[2], label='USENIX Security', color = COLOR3, linewidth = '3', linestyle = Style3)
p4, = plt.plot(year_range, counts_per_dict[3], label='SOUPS', color = COLOR4, linewidth = '3', linestyle = Style4)
p5, = plt.plot(year_range, counts_per_dict[4], label='IEEE S&P', color = COLOR5, linewidth = '3', linestyle = Style5) 
p6, = plt.plot(year_range, counts_per_dict[5], label='IMC', color = COLOR6, linewidth = '3', linestyle = Style6) 
p7, = plt.plot(year_range, sum_count, label='Sum', color = COLOR7, linewidth = '3', linestyle = Style7) 


plt.ylim(0, 6.1)
plt.xlim(year_range[0] - pd.DateOffset(months=1), year_range[-1] + pd.DateOffset(months=1))

plt.xlabel('From 2000 to 2025', fontsize=24, labelpad=10)
plt.ylabel('Paper Number', fontsize=24)
plt.xticks(x_ticks, x_labels, rotation=30, ha='right', rotation_mode='anchor', fontsize=18)
plt.yticks(np.arange(0, 6, 1), size=24)
plt.grid(True)
plt.tight_layout()
ax = plt.gca()

a = plt.legend(
    [
        p1, p2, p3, p4,
        p5, p6, p7
    ], 
    [
        "ACM CCS", "NDSS", "USENIX Security", "SOUPS",
        "IEEE S&P", "IMC", "Sum"
    ], 
    loc='upper left', 
    fontsize=22, 
    frameon=False, 
    ncol=2
)

plt.savefig('../figs/email_paper.pdf',
            bbox_inches='tight', pad_inches=0.25)
# Out:
# 100%|██████████| 6/6 [00:00<?, ?it/s]

# %% [markdown]
# ### 制作词云

# %%
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from collections import Counter
import string

all_dicts = [
    ccs_dict,
    ndss_dict,
    usenix_sec_dict,
    soups_dict,
    sp_dict,
    imc_dict
]

text_list = []

nltk.download('stopwords')

for one_dict in all_dicts:
    for k, v in one_dict.items():
        for one_v in v:
            text_list.append(one_v)

stop_words = set(stopwords.words('english'))
all_text = " ".join(text_list)

cleaned_text = all_text.translate(str.maketrans('', '', string.punctuation))
words = cleaned_text.lower().split()
filtered_words = [word for word in words if word not in stop_words]
cleaned_text = " ".join(filtered_words)

wordcloud = WordCloud(width=1200, height=1600, background_color="white").generate(cleaned_text)


plt.figure(figsize=(12, 16))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")  # 关闭坐标轴
plt.title("", fontsize=16)
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fuyan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
